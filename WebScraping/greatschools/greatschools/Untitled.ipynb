# %%
import pandas as pd

# %%
profileDf = pd.read_csv('school_profiles.csv')

# %%
list(profileDf['overviewlink'])
# Out:
# ['https://www.greatschools.org/california/alpine/5785-Alpine-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/alpine/5786-Boulder-Oaks-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/san-gabriel/2910-Jefferson-Middle-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/pine-valley/5984-Mountain-Empire-High-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/san-diego/6236-Sessions-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/bonsall/5789-Bonsall-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/bonsall/31970-Bonsall-High/?s_cid=gsapi',
#  'https://www.greatschools.org/california/oceanside/14993-Bonsall-West-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/oceanside/12226-Nichols-Elementary-School/?s_cid=gsapi',
#  'https://www.greatschools.org/california/la-mesa/5973-Parkway-Middle-School/?s_cid=gsapi',
# ...

# %%
url = list(profileDf['overviewlink'])[0]

# %%
url.rsplit('/', 2)[-2].split("-")[0]
# Out:
# '5785'
